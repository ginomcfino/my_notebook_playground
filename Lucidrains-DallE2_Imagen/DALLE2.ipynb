# %%
import torch
from dalle2_pytorch import CLIP
# Out:
# /Users/ginomcfino/Library/Python/3.8/lib/python/site-packages/torch/autocast_mode.py:162: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')

# %%
clip =
